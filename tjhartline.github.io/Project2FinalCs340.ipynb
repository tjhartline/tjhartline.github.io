# %%
# Tammy Hartline
# CS-340
# Final Project
# Interactive Dashboard coded with Python/Uses MongoDB integration
# October 2023

# Setup the Jupyter version of Dash
from jupyter_dash import JupyterDash

# Configure the necessary Python module imports for dashboard components
import dash
import dash_leaflet as dl
from dash import dcc
from dash import html
from dash.dependencies import Input, Output, State
import plotly.express as px  # For heatmap
from dash import dash_table
import base64

# Configure OS routines
import os

# Configure the plotting routines
import pandas as pd

# Change 'animal_shelter' and 'AnimalShelter' to match your CRUD Python module file name and class name
from module import AnimalShelter

# Data Manipulation / Model
# Update with your username and password and CRUD Python module name
username = "aacuser"
password = "adminPassword"
host = os.getenv('MONGO_HOST', 'nv-desktop-services.apporto.com')  # Default to set host
port = int(os.getenv('MONGO_PORT', 30336))  # Default to set port
db = 'AAC'
col = 'animals'
shelter = AnimalShelter(username, password, host, port, db, col)

# Class read method must support return of a list object and accept projection JSON input.
# Sending the read method an empty document requests all documents be returned.
df = pd.DataFrame.from_records(shelter.read({}))

# MongoDB v5+ is going to return the '_id' column, which will cause the data_table to crash. So, we remove it here.
# The df.drop command allows us to drop the column. If we do not set inplace=True, it will return a new dataframe
# that does not contain the dropped column(s).
df.drop(columns=['_id'], inplace=True)

# Dashboard Layout / View
app = JupyterDash(__name__)

# Add in Grazioso Salvare’s logo
image_filename = 'Grazioso_Salvare_Logo.png'
encoded_image = base64.b64encode(open(image_filename, 'rb').read())

# Place the HTML image tag in the line below into the app.layout code according to your design.
# Also, remember to include a unique identifier such as your name or date.
# html.Img(src='data:image/png;base64,{}'.format(encoded_image.decode()))

# Create global variables to populate filtered data

# Get each animal type in the collection (distinct, no duplicates)
unq_animal_types = df['animal_type'].unique()
data = df.to_dict('records')
app.layout = html.Div([
    html.Center(html.B(html.H1('SNHU CS-340 Dashboard'))),
    html.Center(html.B(html.H1("Tammy Hartline's Grazioso Salvare DashBoard Final Project"))),
    html.Hr(),

    # Row 1: Header and Photo
    html.Div([
        html.Div(id='header', className='col-6', style={'text-align': 'center'}),
        html.Div([
            html.Img(id='customer-logo', src='data:image/png;base64,{}'.format(encoded_image.decode()),
                     alt='customer logo image'),
        ], className='col-6', style={'display': 'flex', 'justify-content': 'center', 'align-items': 'center'}),
    ], className='row'),

    # Row 2: Buttons for Animal Types and Radio Buttons
    html.Div([
        html.Div([
            html.Button('All', id='btn-all', n_clicks=0),
            *[html.Button(animal_type, id=f'btn-{animal_type}', n_clicks=0) for animal_type in unq_animal_types]
        ], className='col-6'),
        html.Div([
            dcc.RadioItems(
                id='rescue-filter',
                options=[
                    {'label': 'Water Rescue', 'value': 'water'},
                    {'label': 'Mountain and Wilderness Rescue', 'value': 'mount'},
                    {'label': 'Disaster and Individual Tracking', 'value': 'disaster'},
                    {'label': 'Reset', 'value': 'reset'}
                ],
                value='reset',
            ),
        ], className='col-6', id='radio-buttons'),  # Give it an ID for callback
    ], className='row'),

    # Row 3: Data Table and Breed Count
    html.Div([
        dash_table.DataTable(
            id='datatable-id',
            columns=[
                {"name": i, "id": i, "deletable": False, "selectable": True} for i in df.columns
            ],
            data=data,
            # Set up the features for your interactive data table to make it user-friendly for your client.
            # If you completed the Module Six Assignment, you can copy in the code you created here.
            editable=False,
            sort_action="native",
            sort_mode="multi",
            selected_rows=[0],
            filter_action="native",
            page_action="native",
            page_current=0,
            page_size=10,
        ),
    ], className='row'),

    # Row 4: Graph and Map
    html.Div([
        dcc.Graph(id='bubble-plot', className='col-6'),  # Use dcc.Graph for bubble-plot
        html.Div([
            html.Div(id='graph-id', className='col-12'),  # Update the size to col-12
            html.Div(id='map-id', className='col-12'),  # Update the size to col-12
        ], className='col-6'),
    ], className='row'),

    # Row 5: Breed Count
    html.Div(id='breed-count'),

], style={'display': 'flex', 'flex-direction': 'column'})
# Out:
# Query received: {}, type: <class 'dict'>
#
#
# {'_id': ObjectId('6514ce37fe7329bea5cd14f1'), 'rec_num': 1, 'age_upon_outcome': '3 years', 'animal_id': 'A746874', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Black/White', 'date_of_birth': '2014-04-10', 'datetime': '2017-04-11 09:00:00', 'monthyear': '2017-04-11T09:00:00', 'name': '', 'outcome_subtype': 'SCRP', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5066578739455, 'location_long': -97.3408780722188, 'age_upon_outcome_in_weeks': 156.767857142857, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14f2'), 'rec_num': 2, 'age_upon_outcome': '1 year', 'animal_id': 'A725717', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Silver Tabby', 'date_of_birth': '2015-05-02', 'datetime': '2016-05-06 10:49:00', 'monthyear': '2016-05-06T10:49:00', 'name': '', 'outcome_subtype': 'SCRP', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.6525984560228, 'location_long': -97.7419963476444, 'age_upon_outcome_in_weeks': 52.9215277777778, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14f3'), 'rec_num': 5, 'age_upon_outcome': '2 years', 'animal_id': 'A691584', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'color': 'Tan/White', 'date_of_birth': '2012-11-06', 'datetime': '2015-05-30 13:48:00', 'monthyear': '2015-05-30T13:48:00', 'name': 'Luke', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.7104815618433, 'location_long': -97.562297435286, 'age_upon_outcome_in_weeks': 133.653571428571, 'rescue_type': 'water'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14f4'), 'rec_num': 4, 'age_upon_outcome': '7 months', 'animal_id': 'A733653', 'animal_type': 'Cat', 'breed': 'Siamese Mix', 'color': 'Seal Point', 'date_of_birth': '2016-01-25', 'datetime': '2016-08-27 18:11:00', 'monthyear': '2016-08-27T18:11:00', 'name': 'Kitty', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.3188063374257, 'location_long': -97.7240376703891, 'age_upon_outcome_in_weeks': 30.8225198412698, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14f5'), 'rec_num': 7, 'age_upon_outcome': '2 years', 'animal_id': 'A673830', 'animal_type': 'Dog', 'breed': 'Pit Bull Mix', 'color': 'Black/White', 'date_of_birth': '2012-03-03', 'datetime': '2014-03-19 15:15:00', 'monthyear': '2014-03-19T15:15:00', 'name': '*Seth', 'outcome_subtype': 'Aggressive', 'outcome_type': 'Euthanasia', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.2954256583441, 'location_long': -97.3136642110436, 'age_upon_outcome_in_weeks': 106.662202380952, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14f6'), 'rec_num': 9, 'age_upon_outcome': '3 years', 'animal_id': 'A720214', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'color': 'Red/White', 'date_of_birth': '2013-02-04', 'datetime': '2016-02-11 12:41:00', 'monthyear': '2016-02-11T12:41:00', 'name': 'Blessing', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.3870648199411, 'location_long': -97.3684339731375, 'age_upon_outcome_in_weeks': 157.504067460317, 'rescue_type': 'water'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14f7'), 'rec_num': 6, 'age_upon_outcome': '5 years', 'animal_id': 'A696004', 'animal_type': 'Dog', 'breed': 'Cardigan Welsh Corgi Mix', 'color': 'Sable/White', 'date_of_birth': '2010-01-27', 'datetime': '2015-01-28 10:39:00', 'monthyear': '2015-01-28T10:39:00', 'name': 'Lucy', 'outcome_subtype': 'Rabies Risk', 'outcome_type': 'Euthanasia', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.6737365854231, 'location_long': -97.707971529467, 'age_upon_outcome_in_weeks': 261.063392857143, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14f8'), 'rec_num': 8, 'age_upon_outcome': '1 year', 'animal_id': 'A736551', 'animal_type': 'Dog', 'breed': 'Labrador Retriever/Australian Cattle Dog', 'color': 'Black', 'date_of_birth': '2015-10-12', 'datetime': '2016-11-27 18:00:00', 'monthyear': '2016-11-27T18:00:00', 'name': '*Mia', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4443212820182, 'location_long': -97.7326980338793, 'age_upon_outcome_in_weeks': 58.9642857142857, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14f9'), 'rec_num': 11, 'age_upon_outcome': '1 year', 'animal_id': 'A721199', 'animal_type': 'Dog', 'breed': 'Dachshund Wirehair Mix', 'color': 'Tan/White', 'date_of_birth': '2015-02-23', 'datetime': '2016-02-27 17:49:00', 'monthyear': '2016-02-27T17:49:00', 'name': 'Belle', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.7290272761146, 'location_long': -97.3753328216134, 'age_upon_outcome_in_weeks': 52.8203373015873, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14fa'), 'rec_num': 10, 'age_upon_outcome': '3 months', 'animal_id': 'A664290', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Tortie', 'date_of_birth': '2013-09-01', 'datetime': '2013-12-08 14:58:00', 'monthyear': '2013-12-08T14:58:00', 'name': '*Taylor', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.7583105481048, 'location_long': -97.618292198845, 'age_upon_outcome_in_weeks': 14.0890873015873, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14fb'), 'rec_num': 12, 'age_upon_outcome': '1 year', 'animal_id': 'A664843', 'animal_type': 'Dog', 'breed': 'Pit Bull Mix', 'color': 'Brown/White', 'date_of_birth': '2013-06-09', 'datetime': '2014-08-18 17:24:00', 'monthyear': '2014-08-18T17:24:00', 'name': 'Sherlock', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.4515549397366, 'location_long': -97.474104510925, 'age_upon_outcome_in_weeks': 62.2464285714286, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14fc'), 'rec_num': 13, 'age_upon_outcome': '1 year', 'animal_id': 'A700408', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby/White', 'date_of_birth': '2014-04-13', 'datetime': '2015-04-15 13:34:00', 'monthyear': '2015-04-15T13:34:00', 'name': 'Nyla', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4101154527976, 'location_long': -97.562415670838, 'age_upon_outcome_in_weeks': 52.5093253968254, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14fd'), 'rec_num': 14, 'age_upon_outcome': '2 years', 'animal_id': 'A742287', 'animal_type': 'Dog', 'breed': 'Boxer/Bullmastiff', 'color': 'Brown Brindle/White', 'date_of_birth': '2015-01-18', 'datetime': '2017-02-11 12:30:00', 'monthyear': '2017-02-11T12:30:00', 'name': '*Kawhi', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.4551148649096, 'location_long': -97.3087780473978, 'age_upon_outcome_in_weeks': 107.931547619048, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14fe'), 'rec_num': 15, 'age_upon_outcome': '3 years', 'animal_id': 'A712638', 'animal_type': 'Dog', 'breed': 'Pit Bull Mix', 'color': 'Red/White', 'date_of_birth': '2012-09-26', 'datetime': '2016-07-18 17:52:00', 'monthyear': '2016-07-18T17:52:00', 'name': 'Marcus', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5798299207017, 'location_long': -97.5588487936533, 'age_upon_outcome_in_weeks': 198.820634920635, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd14ff'), 'rec_num': 3, 'age_upon_outcome': '2 years', 'animal_id': 'A716330', 'animal_type': 'Dog', 'breed': 'Chihuahua Shorthair Mix', 'color': 'Brown/White', 'date_of_birth': '2013-11-18', 'datetime': '2015-12-28 18:43:00', 'monthyear': '2015-12-28T18:43:00', 'name': 'Frank', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.7595748121648, 'location_long': -97.5523753807133, 'age_upon_outcome_in_weeks': 110.111408730159, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1500'), 'rec_num': 23, 'age_upon_outcome': '2 years', 'animal_id': 'A692137', 'animal_type': 'Dog', 'breed': 'Pit Bull Mix', 'color': 'Blue/White', 'date_of_birth': '2013-05-15', 'datetime': '2016-03-01 15:26:00', 'monthyear': '2016-03-01T15:26:00', 'name': 'Shadow', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Male', 'location_lat': 30.3691596527395, 'location_long': -97.3810871961031, 'age_upon_outcome_in_weeks': 145.949007936508, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1501'), 'rec_num': 24, 'age_upon_outcome': '3 weeks', 'animal_id': 'A704707', 'animal_type': 'Cat', 'breed': 'Siamese Mix', 'color': 'Seal Point', 'date_of_birth': '2015-05-17', 'datetime': '2015-06-08 16:25:00', 'monthyear': '2015-06-08T16:25:00', 'name': '', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Unknown', 'location_lat': 30.7099356408815, 'location_long': -97.6968533378074, 'age_upon_outcome_in_weeks': 3.2405753968254, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1502'), 'rec_num': 25, 'age_upon_outcome': '2 months', 'animal_id': 'A725966', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Tortie', 'date_of_birth': '2016-03-20', 'datetime': '2016-05-24 11:01:00', 'monthyear': '2016-05-24T11:01:00', 'name': '*Star', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.5201707620679, 'location_long': -97.5317824337026, 'age_upon_outcome_in_weeks': 9.35128968253968, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1503'), 'rec_num': 18, 'age_upon_outcome': '2 months', 'animal_id': 'A693288', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby/White', 'date_of_birth': '2014-09-28', 'datetime': '2014-12-09 18:36:00', 'monthyear': '2014-12-09T18:36:00', 'name': '', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4527678292931, 'location_long': -97.4620507167676, 'age_upon_outcome_in_weeks': 10.3964285714286, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1504'), 'rec_num': 26, 'age_upon_outcome': '1 year', 'animal_id': 'A743231', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Black', 'date_of_birth': '2016-02-06', 'datetime': '2017-02-07 09:00:00', 'monthyear': '2017-02-07T09:00:00', 'name': '', 'outcome_subtype': 'SCRP', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.2920163966506, 'location_long': -97.4266291874198, 'age_upon_outcome_in_weeks': 52.4821428571429, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1505'), 'rec_num': 27, 'age_upon_outcome': '2 years', 'animal_id': 'A764418', 'animal_type': 'Dog', 'breed': 'Chihuahua Shorthair Mix', 'color': 'Tan/White', 'date_of_birth': '2015-12-29', 'datetime': '2017-12-30 11:58:00', 'monthyear': '2017-12-30T11:58:00', 'name': 'Burro', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.277168944418, 'location_long': -97.7122755507492, 'age_upon_outcome_in_weeks': 104.642658730159, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1506'), 'rec_num': 20, 'age_upon_outcome': '1 year', 'animal_id': 'A693126', 'animal_type': 'Dog', 'breed': 'American Bulldog Mix', 'color': 'White/Brown', 'date_of_birth': '2013-12-02', 'datetime': '2015-02-28 17:42:00', 'monthyear': '2015-02-28T17:42:00', 'name': 'George', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.577712300078, 'location_long': -97.6438826598467, 'age_upon_outcome_in_weeks': 64.8196428571429, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1507'), 'rec_num': 28, 'age_upon_outcome': '1 year', 'animal_id': 'A743879', 'animal_type': 'Dog', 'breed': 'Pit Bull Mix', 'color': 'Black/White', 'date_of_birth': '2016-02-18', 'datetime': '2017-06-16 14:58:00', 'monthyear': '2017-06-16T14:58:00', 'name': '*Tallulah', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.757367526077, 'location_long': -97.4667421648321, 'age_upon_outcome_in_weeks': 69.2319444444445, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1508'), 'rec_num': 29, 'age_upon_outcome': '2 months', 'animal_id': 'A756064', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Blue', 'date_of_birth': '2017-06-13', 'datetime': '2017-08-16 00:00:00', 'monthyear': '2017-08-16T00:00:00', 'name': '', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Male', 'location_lat': 30.2934116611166, 'location_long': -97.2901948420822, 'age_upon_outcome_in_weeks': 9.14285714285714, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1509'), 'rec_num': 19, 'age_upon_outcome': '4 months', 'animal_id': 'A709511', 'animal_type': 'Cat', 'breed': 'Domestic Medium Hair Mix', 'color': 'White/Black', 'date_of_birth': '2015-07-10', 'datetime': '2015-11-13 14:00:00', 'monthyear': '2015-11-13T14:00:00', 'name': '*Toad', 'outcome_subtype': 'Foster', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5202877527245, 'location_long': -97.6574204375118, 'age_upon_outcome_in_weeks': 18.0833333333333, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd150a'), 'rec_num': 16, 'age_upon_outcome': '5 years', 'animal_id': 'A723742', 'animal_type': 'Dog', 'breed': 'Miniature Schnauzer Mix', 'color': 'Black/White', 'date_of_birth': '2011-04-05', 'datetime': '2016-04-10 17:27:00', 'monthyear': '2016-04-10T17:27:00', 'name': 'Gretchen', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4792884863566, 'location_long': -97.4088531587999, 'age_upon_outcome_in_weeks': 261.818154761905, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd150b'), 'rec_num': 22, 'age_upon_outcome': '5 years', 'animal_id': 'A615748', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'color': 'Black', 'date_of_birth': '2009-12-11', 'datetime': '2015-10-26 18:13:00', 'monthyear': '2015-10-26T18:13:00', 'name': 'Blackie', 'outcome_subtype': 'Suffering', 'outcome_type': 'Euthanasia', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.7172069757685, 'location_long': -97.2952833147647, 'age_upon_outcome_in_weeks': 306.537003968254, 'rescue_type': 'water'}
# {'_id': ObjectId('6514ce37fe7329bea5cd150c'), 'rec_num': 21, 'age_upon_outcome': '2 years', 'animal_id': 'A730354', 'animal_type': 'Dog', 'breed': 'Pit Bull Mix', 'color': 'Blue/White', 'date_of_birth': '2015-07-02', 'datetime': '2017-07-01 18:11:00', 'monthyear': '2017-07-01T18:11:00', 'name': 'Mia', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4815689674138, 'location_long': -97.3694960927915, 'age_upon_outcome_in_weeks': 104.393948412698, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd150d'), 'rec_num': 30, 'age_upon_outcome': '3 years', 'animal_id': 'A648094', 'animal_type': 'Dog', 'breed': 'Dachshund/Chihuahua Shorthair', 'color': 'Red', 'date_of_birth': '2012-11-21', 'datetime': '2016-07-21 18:58:00', 'monthyear': '2016-07-21T18:58:00', 'name': 'Brawndo', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.7173271019582, 'location_long': -97.4883408278017, 'age_upon_outcome_in_weeks': 191.255753968254, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd150e'), 'rec_num': 31, 'age_upon_outcome': '5 years', 'animal_id': 'A651202', 'animal_type': 'Dog', 'breed': 'Maltese Mix', 'color': 'White', 'date_of_birth': '2009-04-07', 'datetime': '2014-09-06 17:11:00', 'monthyear': '2014-09-06T17:11:00', 'name': 'Daisy', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4874006446211, 'location_long': -97.7300741137765, 'age_upon_outcome_in_weeks': 282.67371031746, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd150f'), 'rec_num': 17, 'age_upon_outcome': '6 months', 'animal_id': 'A668960', 'animal_type': 'Dog', 'breed': 'Pit Bull Mix', 'color': 'Blue/White', 'date_of_birth': '2013-06-12', 'datetime': '2013-12-27 16:56:00', 'monthyear': '2013-12-27T16:56:00', 'name': '*Gigi', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.5943410758588, 'location_long': -97.2489933569515, 'age_upon_outcome_in_weeks': 28.3865079365079, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1510'), 'rec_num': 39, 'age_upon_outcome': '1 year', 'animal_id': 'A707145', 'animal_type': 'Dog', 'breed': 'Dachshund Mix', 'color': 'Brown/White', 'date_of_birth': '2014-07-08', 'datetime': '2015-07-10 14:01:00', 'monthyear': '2015-07-10T14:01:00', 'name': 'Puppy', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.3262557645033, 'location_long': -97.5826548089348, 'age_upon_outcome_in_weeks': 52.512003968254, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1511'), 'rec_num': 38, 'age_upon_outcome': '2 months', 'animal_id': 'A760125', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'White/Black', 'date_of_birth': '2017-07-29', 'datetime': '2017-10-17 00:00:00', 'monthyear': '2017-10-17T00:00:00', 'name': '', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5414256979756, 'location_long': -97.4633994244696, 'age_upon_outcome_in_weeks': 11.4285714285714, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1512'), 'rec_num': 40, 'age_upon_outcome': '2 months', 'animal_id': 'A710726', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Torbie', 'date_of_birth': '2015-08-04', 'datetime': '2015-10-24 18:17:00', 'monthyear': '2015-10-24T18:17:00', 'name': '*Zara', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.3850058790273, 'location_long': -97.5209209803692, 'age_upon_outcome_in_weeks': 11.6802579365079, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1513'), 'rec_num': 34, 'age_upon_outcome': '3 months', 'animal_id': 'A753983', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Orange Tabby', 'date_of_birth': '2017-04-13', 'datetime': '2017-07-16 19:19:00', 'monthyear': '2017-07-16T19:19:00', 'name': '', 'outcome_subtype': 'Snr', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Unknown', 'location_lat': 30.4301887696662, 'location_long': -97.5837553641966, 'age_upon_outcome_in_weeks': 13.5435515873016, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1514'), 'rec_num': 41, 'age_upon_outcome': '2 years', 'animal_id': 'A699587', 'animal_type': 'Dog', 'breed': 'Miniature Poodle Mix', 'color': 'White', 'date_of_birth': '2013-03-30', 'datetime': '2015-04-03 17:26:00', 'monthyear': '2015-04-03T17:26:00', 'name': 'Paisley', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.28807307007, 'location_long': -97.7083036718567, 'age_upon_outcome_in_weeks': 104.960912698413, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1515'), 'rec_num': 44, 'age_upon_outcome': '8 years', 'animal_id': 'A724746', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Orange Tabby', 'date_of_birth': '2008-04-21', 'datetime': '2016-04-22 14:25:00', 'monthyear': '2016-04-22T14:25:00', 'name': '', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Male', 'location_lat': 30.3734825413611, 'location_long': -97.4876534656943, 'age_upon_outcome_in_weeks': 417.657242063492, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1516'), 'rec_num': 36, 'age_upon_outcome': '6 months', 'animal_id': 'A706953', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'color': 'Yellow', 'date_of_birth': '2014-12-06', 'datetime': '2015-07-06 11:33:00', 'monthyear': '2015-07-06T11:33:00', 'name': '', 'outcome_subtype': 'Medical', 'outcome_type': 'Euthanasia', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.5480802368633, 'location_long': -97.2969969058957, 'age_upon_outcome_in_weeks': 30.3544642857143, 'rescue_type': 'water'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1517'), 'rec_num': 43, 'age_upon_outcome': '2 years', 'animal_id': 'A697233', 'animal_type': 'Dog', 'breed': 'Pit Bull Mix', 'color': 'Tan/White', 'date_of_birth': '2013-02-20', 'datetime': '2015-04-05 14:10:00', 'monthyear': '2015-04-05T14:10:00', 'name': '*Tolliver', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.3091899182072, 'location_long': -97.407391329783, 'age_upon_outcome_in_weeks': 110.655753968254, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1518'), 'rec_num': 42, 'age_upon_outcome': '1 year', 'animal_id': 'A691043', 'animal_type': 'Dog', 'breed': 'Pug/Chihuahua Shorthair', 'color': 'Tan/Black', 'date_of_birth': '2013-07-29', 'datetime': '2014-11-02 12:50:00', 'monthyear': '2014-11-02T12:50:00', 'name': 'Thor', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Male', 'location_lat': 30.6024909051342, 'location_long': -97.5565461484622, 'age_upon_outcome_in_weeks': 65.9335317460317, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1519'), 'rec_num': 45, 'age_upon_outcome': '6 years', 'animal_id': 'A674774', 'animal_type': 'Dog', 'breed': 'German Shepherd/Labrador Retriever', 'color': 'Brown/Black', 'date_of_birth': '2008-03-18', 'datetime': '2014-03-19 17:06:00', 'monthyear': '2014-03-19T17:06:00', 'name': 'Brownie', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.6586627849508, 'location_long': -97.5814399775041, 'age_upon_outcome_in_weeks': 313.244642857143, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd151a'), 'rec_num': 46, 'age_upon_outcome': '1 month', 'animal_id': 'A683445', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Orange Tabby/White', 'date_of_birth': '2014-06-03', 'datetime': '2014-07-17 07:55:00', 'monthyear': '2014-07-17T07:55:00', 'name': '*Blynn', 'outcome_subtype': 'In Kennel', 'outcome_type': 'Died', 'sex_upon_outcome': 'Intact Male', 'location_lat': 30.4948425592226, 'location_long': -97.4588853059737, 'age_upon_outcome_in_weeks': 6.3328373015873, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd151b'), 'rec_num': 48, 'age_upon_outcome': '1 year', 'animal_id': 'A689217', 'animal_type': 'Dog', 'breed': 'Australian Cattle Dog/Beagle', 'color': 'White/Red', 'date_of_birth': '2013-09-30', 'datetime': '2014-10-11 19:10:00', 'monthyear': '2014-10-11T19:10:00', 'name': 'Hot Dog', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.370784054406, 'location_long': -97.377875081342, 'age_upon_outcome_in_weeks': 53.828373015873, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd151c'), 'rec_num': 47, 'age_upon_outcome': '3 years', 'animal_id': 'A672401', 'animal_type': 'Dog', 'breed': 'Siberian Husky Mix', 'color': 'Red/White', 'date_of_birth': '2011-02-09', 'datetime': '2014-02-09 18:36:00', 'monthyear': '2014-02-09T18:36:00', 'name': 'Ziegen', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5731136081642, 'location_long': -97.43700344702, 'age_upon_outcome_in_weeks': 156.682142857143, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd151d'), 'rec_num': 37, 'age_upon_outcome': '3 months', 'animal_id': 'A739519', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby', 'date_of_birth': '2016-11-06', 'datetime': '2017-02-11 18:46:00', 'monthyear': '2017-02-11T18:46:00', 'name': 'Mojito', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.6831812834341, 'location_long': -97.2458191635746, 'age_upon_outcome_in_weeks': 13.9688492063492, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd151e'), 'rec_num': 32, 'age_upon_outcome': '3 months', 'animal_id': 'A687515', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Orange Tabby', 'date_of_birth': '2014-05-29', 'datetime': '2014-09-07 18:30:00', 'monthyear': '2014-09-07T18:30:00', 'name': 'Dinah', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.5370536731062, 'location_long': -97.5684815578894, 'age_upon_outcome_in_weeks': 14.5386904761905, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd151f'), 'rec_num': 33, 'age_upon_outcome': '2 years', 'animal_id': 'A709958', 'animal_type': 'Dog', 'breed': 'Australian Cattle Dog Mix', 'color': 'Brown Brindle/White', 'date_of_birth': '2013-08-15', 'datetime': '2015-08-23 19:23:00', 'monthyear': '2015-08-23T19:23:00', 'name': 'Jack', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.6937385067567, 'location_long': -97.5766003196181, 'age_upon_outcome_in_weeks': 105.543948412698, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1520'), 'rec_num': 51, 'age_upon_outcome': '2 years', 'animal_id': 'A680890', 'animal_type': 'Dog', 'breed': 'Miniature Poodle', 'color': 'White', 'date_of_birth': '2012-06-09', 'datetime': '2014-06-09 18:21:00', 'monthyear': '2014-06-09T18:21:00', 'name': '', 'outcome_subtype': 'Suffering', 'outcome_type': 'Euthanasia', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.3319903337122, 'location_long': -97.556817439575, 'age_upon_outcome_in_weeks': 104.39494047619, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1521'), 'rec_num': 56, 'age_upon_outcome': '1 month', 'animal_id': 'A728660', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby', 'date_of_birth': '2016-05-05', 'datetime': '2016-06-30 13:25:00', 'monthyear': '2016-06-30T13:25:00', 'name': 'Misty', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.3384118987052, 'location_long': -97.5099376814615, 'age_upon_outcome_in_weeks': 8.07986111111111, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1522'), 'rec_num': 57, 'age_upon_outcome': '7 years', 'animal_id': 'A754845', 'animal_type': 'Dog', 'breed': 'Chow Chow Mix', 'color': 'Tan', 'date_of_birth': '2010-08-12', 'datetime': '2017-08-17 16:03:00', 'monthyear': '2017-08-17T16:03:00', 'name': 'Coco', 'outcome_subtype': '', 'outcome_type': 'Rto-Adopt', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.5499038787221, 'location_long': -97.7055343025446, 'age_upon_outcome_in_weeks': 366.095535714286, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1523'), 'rec_num': 54, 'age_upon_outcome': '1 year', 'animal_id': 'A715512', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Orange Tabby', 'date_of_birth': '2014-11-05', 'datetime': '2016-01-04 00:00:00', 'monthyear': '2016-01-04T00:00:00', 'name': '*Lola', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.560261054965, 'location_long': -97.298122147497, 'age_upon_outcome_in_weeks': 60.7142857142857, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1524'), 'rec_num': 53, 'age_upon_outcome': '4 weeks', 'animal_id': 'A752695', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby/White', 'date_of_birth': '2017-05-26', 'datetime': '2017-06-27 15:07:00', 'monthyear': '2017-06-27T15:07:00', 'name': '', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Male', 'location_lat': 30.3465931591785, 'location_long': -97.3104071716501, 'age_upon_outcome_in_weeks': 4.66140873015873, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1525'), 'rec_num': 52, 'age_upon_outcome': '1 weeks', 'animal_id': 'A723050', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby', 'date_of_birth': '2016-03-12', 'datetime': '2016-03-25 18:49:00', 'monthyear': '2016-03-25T18:49:00', 'name': '', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Male', 'location_lat': 30.3557252644792, 'location_long': -97.5743300659894, 'age_upon_outcome_in_weeks': 1.96914682539683, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1526'), 'rec_num': 49, 'age_upon_outcome': '8 years', 'animal_id': 'A742234', 'animal_type': 'Dog', 'breed': 'Yorkshire Terrier Mix', 'color': 'Brown/Black', 'date_of_birth': '2009-01-18', 'datetime': '2017-01-28 11:17:00', 'monthyear': '2017-01-28T11:17:00', 'name': 'Coco', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.3571792790617, 'location_long': -97.5467092518215, 'age_upon_outcome_in_weeks': 418.924305555556, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1527'), 'rec_num': 58, 'age_upon_outcome': '1 year', 'animal_id': 'A730275', 'animal_type': 'Dog', 'breed': 'Chinese Sharpei Mix', 'color': 'Brown', 'date_of_birth': '2015-07-01', 'datetime': '2016-07-09 17:53:00', 'monthyear': '2016-07-09T17:53:00', 'name': 'Chai', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.5813151102997, 'location_long': -97.6206629031585, 'age_upon_outcome_in_weeks': 53.5350198412698, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1528'), 'rec_num': 50, 'age_upon_outcome': '2 years', 'animal_id': 'A721406', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'color': 'Cream/White', 'date_of_birth': '2014-02-26', 'datetime': '2016-05-04 00:00:00', 'monthyear': '2016-05-04T00:00:00', 'name': 'Lanie', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4095171307439, 'location_long': -97.4146768727431, 'age_upon_outcome_in_weeks': 114, 'rescue_type': 'water'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1529'), 'rec_num': 55, 'age_upon_outcome': '6 years', 'animal_id': 'A699222', 'animal_type': 'Dog', 'breed': 'Beagle Mix', 'color': 'Tricolor', 'date_of_birth': '2009-06-14', 'datetime': '2015-06-19 18:43:00', 'monthyear': '2015-06-19T18:43:00', 'name': 'Scruffy', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.7539956876934, 'location_long': -97.6406095439333, 'age_upon_outcome_in_weeks': 313.825694444444, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd152a'), 'rec_num': 35, 'age_upon_outcome': '7 years', 'animal_id': 'A712377', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby/White', 'date_of_birth': '2008-09-22', 'datetime': '2015-09-23 09:00:00', 'monthyear': '2015-09-23T09:00:00', 'name': '', 'outcome_subtype': 'SCRP', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5914919451752, 'location_long': -97.6417061435299, 'age_upon_outcome_in_weeks': 365.339285714286, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd152b'), 'rec_num': 60, 'age_upon_outcome': '2 months', 'animal_id': 'A716822', 'animal_type': 'Dog', 'breed': 'Dachshund Mix', 'color': 'Red/White', 'date_of_birth': '2015-09-18', 'datetime': '2015-11-30 16:53:00', 'monthyear': '2015-11-30T16:53:00', 'name': '*Sally', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.5205750485563, 'location_long': -97.2918628227555, 'age_upon_outcome_in_weeks': 10.5290674603175, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd152c'), 'rec_num': 59, 'age_upon_outcome': '4 years', 'animal_id': 'A689501', 'animal_type': 'Dog', 'breed': 'Chinese Crested Mix', 'color': 'Black/White', 'date_of_birth': '2010-10-04', 'datetime': '2014-10-09 17:20:00', 'monthyear': '2014-10-09T17:20:00', 'name': '*Ping', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.6794669197802, 'location_long': -97.5734023310214, 'age_upon_outcome_in_weeks': 209.531746031746, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd152d'), 'rec_num': 61, 'age_upon_outcome': '1 year', 'animal_id': 'A751029', 'animal_type': 'Dog', 'breed': 'Staffordshire Mix', 'color': 'Blue/White', 'date_of_birth': '2016-06-03', 'datetime': '2017-06-09 18:23:00', 'monthyear': '2017-06-09T18:23:00', 'name': '', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.3196475861473, 'location_long': -97.5725082134572, 'age_upon_outcome_in_weeks': 53.1094246031746, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd152e'), 'rec_num': 64, 'age_upon_outcome': '1 year', 'animal_id': 'A708999', 'animal_type': 'Dog', 'breed': 'Australian Cattle Dog Mix', 'color': 'Brown Brindle/White', 'date_of_birth': '2014-11-03', 'datetime': '2015-12-15 11:00:00', 'monthyear': '2015-12-15T11:00:00', 'name': '*Daisy', 'outcome_subtype': 'Foster', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4703459246575, 'location_long': -97.6851640454193, 'age_upon_outcome_in_weeks': 58.2083333333333, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd152f'), 'rec_num': 65, 'age_upon_outcome': '10 years', 'animal_id': 'A671822', 'animal_type': 'Dog', 'breed': 'German Shepherd Mix', 'color': 'Black/Tan', 'date_of_birth': '2006-01-31', 'datetime': '2016-10-11 10:03:00', 'monthyear': '2016-10-11T10:03:00', 'name': '*Milo', 'outcome_subtype': 'Foster', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.7118766251975, 'location_long': -97.2999365773623, 'age_upon_outcome_in_weeks': 558.059821428571, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1530'), 'rec_num': 62, 'age_upon_outcome': '1 year', 'animal_id': 'A669824', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'color': 'Black', 'date_of_birth': '2013-07-27', 'datetime': '2014-11-15 15:19:00', 'monthyear': '2014-11-15T15:19:00', 'name': 'Jackson', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.6194338512674, 'location_long': -97.6579352219145, 'age_upon_outcome_in_weeks': 68.0911706349206, 'rescue_type': 'water'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1531'), 'rec_num': 63, 'age_upon_outcome': '2 years', 'animal_id': 'A728144', 'animal_type': 'Dog', 'breed': 'Border Collie/Queensland Heeler', 'color': 'Black/White', 'date_of_birth': '2014-05-31', 'datetime': '2016-06-05 15:43:00', 'monthyear': '2016-06-05T15:43:00', 'name': 'Lilly', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.2947528985168, 'location_long': -97.4279427946485, 'age_upon_outcome_in_weeks': 105.236408730159, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1532'), 'rec_num': 67, 'age_upon_outcome': '12 years', 'animal_id': 'A745946', 'animal_type': 'Dog', 'breed': 'Chihuahua Shorthair', 'color': 'White/Tan', 'date_of_birth': '2005-03-29', 'datetime': '2017-08-07 12:47:00', 'monthyear': '2017-08-07T12:47:00', 'name': '*Toodles', 'outcome_subtype': 'Foster', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.7003350911457, 'location_long': -97.5727489821515, 'age_upon_outcome_in_weeks': 644.933234126984, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1533'), 'rec_num': 66, 'age_upon_outcome': '6 months', 'animal_id': 'A713150', 'animal_type': 'Cat', 'breed': 'Domestic Medium Hair Mix', 'color': 'Blue/White', 'date_of_birth': '2015-04-03', 'datetime': '2015-10-04 09:00:00', 'monthyear': '2015-10-04T09:00:00', 'name': '', 'outcome_subtype': 'SCRP', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Unknown', 'location_lat': 30.6490056542256, 'location_long': -97.3006432681698, 'age_upon_outcome_in_weeks': 26.3392857142857, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1534'), 'rec_num': 69, 'age_upon_outcome': '3 years', 'animal_id': 'A725549', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby/White', 'date_of_birth': '2013-04-30', 'datetime': '2016-06-12 18:13:00', 'monthyear': '2016-06-12T18:13:00', 'name': 'Diz', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.349666302369, 'location_long': -97.3331182841803, 'age_upon_outcome_in_weeks': 162.822718253968, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1535'), 'rec_num': 68, 'age_upon_outcome': '4 years', 'animal_id': 'A752436', 'animal_type': 'Dog', 'breed': 'Yorkshire Terrier Mix', 'color': 'Tricolor', 'date_of_birth': '2013-06-22', 'datetime': '2017-06-23 16:48:00', 'monthyear': '2017-06-23T16:48:00', 'name': 'Rylie', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5804324963125, 'location_long': -97.5404082136154, 'age_upon_outcome_in_weeks': 208.957142857143, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1536'), 'rec_num': 70, 'age_upon_outcome': '3 months', 'animal_id': 'A683276', 'animal_type': 'Other', 'breed': 'Raccoon Mix', 'color': 'Black/Gray', 'date_of_birth': '2014-04-08', 'datetime': '2014-07-09 08:52:00', 'monthyear': '2014-07-09T08:52:00', 'name': '', 'outcome_subtype': 'Rabies Risk', 'outcome_type': 'Euthanasia', 'sex_upon_outcome': 'Unknown', 'location_lat': 30.5106746135701, 'location_long': -97.2826788031676, 'age_upon_outcome_in_weeks': 13.1956349206349, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1537'), 'rec_num': 71, 'age_upon_outcome': '2 years', 'animal_id': 'A762414', 'animal_type': 'Other', 'breed': 'Raccoon', 'color': 'Gray/Black', 'date_of_birth': '2015-11-20', 'datetime': '2017-11-21 08:20:00', 'monthyear': '2017-11-21T08:20:00', 'name': '', 'outcome_subtype': 'Suffering', 'outcome_type': 'Euthanasia', 'sex_upon_outcome': 'Unknown', 'location_lat': 30.3718926151062, 'location_long': -97.4774272170111, 'age_upon_outcome_in_weeks': 104.621031746032, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1538'), 'rec_num': 75, 'age_upon_outcome': '5 months', 'animal_id': 'A734883', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Blue Tabby/White', 'date_of_birth': '2016-04-14', 'datetime': '2016-09-27 22:24:00', 'monthyear': '2016-09-27T22:24:00', 'name': '', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.4984779796621, 'location_long': -97.5930332183412, 'age_upon_outcome_in_weeks': 23.847619047619, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1539'), 'rec_num': 78, 'age_upon_outcome': '1 year', 'animal_id': 'A690377', 'animal_type': 'Dog', 'breed': 'Pit Bull Mix', 'color': 'Black/White', 'date_of_birth': '2013-10-19', 'datetime': '2015-02-20 15:07:00', 'monthyear': '2015-02-20T15:07:00', 'name': '*Pagani', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5804041697432, 'location_long': -97.3441305405284, 'age_upon_outcome_in_weeks': 69.947123015873, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd153a'), 'rec_num': 80, 'age_upon_outcome': '4 months', 'animal_id': 'A687309', 'animal_type': 'Dog', 'breed': 'Miniature Poodle Mix', 'color': 'Cream', 'date_of_birth': '2014-05-03', 'datetime': '2014-09-07 16:48:00', 'monthyear': '2014-09-07T16:48:00', 'name': '', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.349814324788, 'location_long': -97.3355763099762, 'age_upon_outcome_in_weeks': 18.2428571428571, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd153b'), 'rec_num': 77, 'age_upon_outcome': '4 years', 'animal_id': 'A756786', 'animal_type': 'Dog', 'breed': 'Chihuahua Longhair/Yorkshire Terrier', 'color': 'White/Tan', 'date_of_birth': '2013-08-25', 'datetime': '2017-08-28 19:08:00', 'monthyear': '2017-08-28T19:08:00', 'name': 'Bebe', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.4738298856514, 'location_long': -97.567165928853, 'age_upon_outcome_in_weeks': 209.256746031746, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd153c'), 'rec_num': 82, 'age_upon_outcome': '3 years', 'animal_id': 'A723765', 'animal_type': 'Dog', 'breed': 'Queensland Heeler Mix', 'color': 'White/Red Merle', 'date_of_birth': '2013-04-06', 'datetime': '2016-04-06 16:50:00', 'monthyear': '2016-04-06T16:50:00', 'name': 'Dewie', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.2769451914628, 'location_long': -97.3149222912905, 'age_upon_outcome_in_weeks': 156.671626984127, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd153d'), 'rec_num': 81, 'age_upon_outcome': '11 months', 'animal_id': 'A678782', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Black', 'date_of_birth': '2014-03-28', 'datetime': '2015-03-02 15:10:00', 'monthyear': '2015-03-02T15:10:00', 'name': 'Fred', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.2958386572413, 'location_long': -97.5584905456389, 'age_upon_outcome_in_weeks': 48.5188492063492, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd153e'), 'rec_num': 83, 'age_upon_outcome': '4 years', 'animal_id': 'A738497', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby', 'date_of_birth': '2012-11-16', 'datetime': '2016-12-22 13:35:00', 'monthyear': '2016-12-22T13:35:00', 'name': '*Kyleigh', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.6806345179162, 'location_long': -97.6678754502172, 'age_upon_outcome_in_weeks': 213.937996031746, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd153f'), 'rec_num': 84, 'age_upon_outcome': '1 year', 'animal_id': 'A704521', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Orange Tabby', 'date_of_birth': '2014-06-05', 'datetime': '2015-06-24 16:41:00', 'monthyear': '2015-06-24T16:41:00', 'name': '*Goldie', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4989634425086, 'location_long': -97.6751570637692, 'age_upon_outcome_in_weeks': 54.9564484126984, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1540'), 'rec_num': 85, 'age_upon_outcome': '11 years', 'animal_id': 'A323668', 'animal_type': 'Dog', 'breed': 'Australian Cattle Dog Mix', 'color': 'Tricolor', 'date_of_birth': '2003-05-15', 'datetime': '2015-03-06 17:36:00', 'monthyear': '2015-03-06T17:36:00', 'name': 'Ringo', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5079890751536, 'location_long': -97.5534887534599, 'age_upon_outcome_in_weeks': 616.247619047619, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1541'), 'rec_num': 88, 'age_upon_outcome': '7 years', 'animal_id': 'A663438', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'color': 'Sable', 'date_of_birth': '2006-09-18', 'datetime': '2014-06-14 16:40:00', 'monthyear': '2014-06-14T16:40:00', 'name': 'Bonny', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.71339193104, 'location_long': -97.3077552120648, 'age_upon_outcome_in_weeks': 403.813492063492, 'rescue_type': 'water'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1542'), 'rec_num': 86, 'age_upon_outcome': '6 years', 'animal_id': 'A724022', 'animal_type': 'Dog', 'breed': 'Chihuahua Shorthair Mix', 'color': 'Tan/Red', 'date_of_birth': '2011-04-10', 'datetime': '2017-05-24 16:15:00', 'monthyear': '2017-05-24T16:15:00', 'name': 'Pepe', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.4054162302655, 'location_long': -97.5924477988179, 'age_upon_outcome_in_weeks': 319.525297619048, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1543'), 'rec_num': 87, 'age_upon_outcome': '1 year', 'animal_id': 'A724478', 'animal_type': 'Dog', 'breed': 'Flat Coat Retriever Mix', 'color': 'Black', 'date_of_birth': '2015-04-18', 'datetime': '2016-05-04 16:45:00', 'monthyear': '2016-05-04T16:45:00', 'name': 'Shadow', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5265906400911, 'location_long': -97.6402446114754, 'age_upon_outcome_in_weeks': 54.6711309523809, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1544'), 'rec_num': 73, 'age_upon_outcome': '2 months', 'animal_id': 'A666065', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby/White', 'date_of_birth': '2013-08-26', 'datetime': '2013-11-09 18:14:00', 'monthyear': '2013-11-09T18:14:00', 'name': 'Sandy', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.5430287552918, 'location_long': -97.6862435276171, 'age_upon_outcome_in_weeks': 10.8228174603175, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1545'), 'rec_num': 76, 'age_upon_outcome': '10 months', 'animal_id': 'A703777', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Black Smoke', 'date_of_birth': '2015-04-21', 'datetime': '2016-03-11 11:10:00', 'monthyear': '2016-03-11T11:10:00', 'name': 'Whisper', 'outcome_subtype': 'Foster', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4445743241147, 'location_long': -97.3019831691228, 'age_upon_outcome_in_weeks': 46.4950396825397, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1546'), 'rec_num': 72, 'age_upon_outcome': '1 year', 'animal_id': 'A712292', 'animal_type': 'Dog', 'breed': 'Chihuahua Shorthair Mix', 'color': 'Tan/White', 'date_of_birth': '2014-09-20', 'datetime': '2015-09-21 12:18:00', 'monthyear': '2015-09-21T12:18:00', 'name': 'Peanut', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.7645588874433, 'location_long': -97.6304822507824, 'age_upon_outcome_in_weeks': 52.3589285714286, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd1547'), 'rec_num': 74, 'age_upon_outcome': '9 years', 'animal_id': 'A582826', 'animal_type': 'Dog', 'breed': 'Beagle', 'color': 'Tricolor', 'date_of_birth': '2005-08-26', 'datetime': '2015-08-18 11:11:00', 'monthyear': '2015-08-18T11:11:00', 'name': 'Charlie', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.336163516779, 'location_long': -97.4507799807501, 'age_upon_outcome_in_weeks': 520.637996031746, 'rescue_type': 'unknown'}
# ...
# {'_id': ObjectId('6514ce37fe7329bea5cd3be8'), 'rec_num': 9976, 'age_upon_outcome': '1 year', 'animal_id': 'A674123', 'animal_type': 'Other', 'breed': 'Bat Mix', 'color': 'Brown/Black', 'date_of_birth': '2013-03-07', 'datetime': '2014-03-07 16:23:00', 'monthyear': '2014-03-07T16:23:00', 'name': '', 'outcome_subtype': 'Rabies Risk', 'outcome_type': 'Euthanasia', 'sex_upon_outcome': 'Unknown', 'location_lat': 30.749505386492, 'location_long': -97.6719801196556, 'age_upon_outcome_in_weeks': 52.240376984127, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3be9'), 'rec_num': 9980, 'age_upon_outcome': '2 years', 'animal_id': 'A670771', 'animal_type': 'Dog', 'breed': 'Chihuahua Shorthair/Cardigan Welsh Corgi', 'color': 'Tricolor', 'date_of_birth': '2012-01-13', 'datetime': '2014-01-19 13:30:00', 'monthyear': '2014-01-19T13:30:00', 'name': '*Chevy', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.6712063009725, 'location_long': -97.5393255458099, 'age_upon_outcome_in_weeks': 105.366071428571, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bea'), 'rec_num': 9981, 'age_upon_outcome': '1 year', 'animal_id': 'A750332', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby', 'date_of_birth': '2016-05-25', 'datetime': '2017-05-27 13:42:00', 'monthyear': '2017-05-27T13:42:00', 'name': '*Amber', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.293648461598, 'location_long': -97.2992557282129, 'age_upon_outcome_in_weeks': 52.510119047619, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3beb'), 'rec_num': 9986, 'age_upon_outcome': '1 year', 'animal_id': 'A728197', 'animal_type': 'Dog', 'breed': 'Pit Bull Mix', 'color': 'Tan/White', 'date_of_birth': '2014-12-01', 'datetime': '2016-07-23 16:29:00', 'monthyear': '2016-07-23T16:29:00', 'name': '*Lady', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.7132928472422, 'location_long': -97.2894799321767, 'age_upon_outcome_in_weeks': 85.8124007936508, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bec'), 'rec_num': 9984, 'age_upon_outcome': '3 years', 'animal_id': 'A741342', 'animal_type': 'Dog', 'breed': 'Wire Hair Fox Terrier Mix', 'color': 'Brown/Black', 'date_of_birth': '2013-12-31', 'datetime': '2016-12-31 16:52:00', 'monthyear': '2016-12-31T16:52:00', 'name': 'Terry', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4444643621503, 'location_long': -97.6727526098362, 'age_upon_outcome_in_weeks': 156.671825396825, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bed'), 'rec_num': 9985, 'age_upon_outcome': '4 years', 'animal_id': 'A712011', 'animal_type': 'Dog', 'breed': 'Jack Russell Terrier/Chihuahua Shorthair', 'color': 'Tricolor', 'date_of_birth': '2011-09-15', 'datetime': '2015-09-19 12:33:00', 'monthyear': '2015-09-19T12:33:00', 'name': 'Daisy', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.7546877491502, 'location_long': -97.3235000670378, 'age_upon_outcome_in_weeks': 209.360416666667, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bee'), 'rec_num': 9973, 'age_upon_outcome': '4 months', 'animal_id': 'A698823', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'color': 'Yellow', 'date_of_birth': '2014-11-18', 'datetime': '2015-03-22 18:42:00', 'monthyear': '2015-03-22T18:42:00', 'name': 'Nala', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.2892079024198, 'location_long': -97.5271877109313, 'age_upon_outcome_in_weeks': 17.8255952380952, 'rescue_type': 'water'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bef'), 'rec_num': 9989, 'age_upon_outcome': '2 years', 'animal_id': 'A692109', 'animal_type': 'Dog', 'breed': 'German Shepherd Mix', 'color': 'Tricolor', 'date_of_birth': '2012-11-14', 'datetime': '2014-11-18 18:04:00', 'monthyear': '2014-11-18T18:04:00', 'name': 'Ada', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.7617941876217, 'location_long': -97.7062177974016, 'age_upon_outcome_in_weeks': 104.964682539683, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bf0'), 'rec_num': 9987, 'age_upon_outcome': '4 years', 'animal_id': 'A729430', 'animal_type': 'Dog', 'breed': 'Chihuahua Shorthair/Dachshund', 'color': 'Red', 'date_of_birth': '2012-06-18', 'datetime': '2016-06-21 15:58:00', 'monthyear': '2016-06-21T15:58:00', 'name': 'Bandit', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.5077291800328, 'location_long': -97.3809783729594, 'age_upon_outcome_in_weeks': 209.237896825397, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bf1'), 'rec_num': 9988, 'age_upon_outcome': '1 year', 'animal_id': 'A673936', 'animal_type': 'Cat', 'breed': 'Bombay Mix', 'color': 'Black', 'date_of_birth': '2012-11-04', 'datetime': '2014-03-05 11:49:00', 'monthyear': '2014-03-05T11:49:00', 'name': 'Cooper', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.7574406063743, 'location_long': -97.2848052729469, 'age_upon_outcome_in_weeks': 69.4989087301587, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bf2'), 'rec_num': 9990, 'age_upon_outcome': '9 months', 'animal_id': 'A658724', 'animal_type': 'Cat', 'breed': 'Domestic Medium Hair Mix', 'color': 'Brown Tabby', 'date_of_birth': '2013-07-07', 'datetime': '2014-04-20 15:40:00', 'monthyear': '2014-04-20T15:40:00', 'name': '*Tiny', 'outcome_subtype': 'Foster', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.7254057653914, 'location_long': -97.3910915779376, 'age_upon_outcome_in_weeks': 41.093253968254, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bf3'), 'rec_num': 9992, 'age_upon_outcome': '12 years', 'animal_id': 'A680575', 'animal_type': 'Dog', 'breed': 'Chihuahua Shorthair', 'color': 'Black/White', 'date_of_birth': '2002-06-04', 'datetime': '2014-06-12 15:43:00', 'monthyear': '2014-06-12T15:43:00', 'name': 'Gracie', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.3442751976496, 'location_long': -97.3119014107024, 'age_upon_outcome_in_weeks': 627.379265873016, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bf4'), 'rec_num': 9982, 'age_upon_outcome': '1 year', 'animal_id': 'A729491', 'animal_type': 'Dog', 'breed': 'German Shepherd Mix', 'color': 'Chocolate/Tan', 'date_of_birth': '2015-06-20', 'datetime': '2016-06-25 15:32:00', 'monthyear': '2016-06-25T15:32:00', 'name': 'Cracker', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.7272708338601, 'location_long': -97.7235090125189, 'age_upon_outcome_in_weeks': 53.0924603174603, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bf5'), 'rec_num': 9991, 'age_upon_outcome': '6 years', 'animal_id': 'A672341', 'animal_type': 'Dog', 'breed': 'Border Collie Mix', 'color': 'Black/White', 'date_of_birth': '2008-02-08', 'datetime': '2014-02-11 11:10:00', 'monthyear': '2014-02-11T11:10:00', 'name': 'Mischief', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.2932634092371, 'location_long': -97.4424495414933, 'age_upon_outcome_in_weeks': 313.637896825397, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bf6'), 'rec_num': 9974, 'age_upon_outcome': '1 month', 'animal_id': 'A735530', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Blue', 'date_of_birth': '2016-08-16', 'datetime': '2016-09-29 12:41:00', 'monthyear': '2016-09-29T12:41:00', 'name': '*Charlotte', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.630210479764, 'location_long': -97.6449629690314, 'age_upon_outcome_in_weeks': 6.36121031746032, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bf7'), 'rec_num': 9993, 'age_upon_outcome': '2 years', 'animal_id': 'A761792', 'animal_type': 'Dog', 'breed': 'Bichon Frise/Miniature Poodle', 'color': 'White', 'date_of_birth': '2015-05-09', 'datetime': '2017-11-10 14:36:00', 'monthyear': '2017-11-10T14:36:00', 'name': 'Voler', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Male', 'location_lat': 30.5819767764418, 'location_long': -97.3349580686668, 'age_upon_outcome_in_weeks': 130.944047619048, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bf8'), 'rec_num': 9994, 'age_upon_outcome': '2 years', 'animal_id': 'A713640', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Blue/White', 'date_of_birth': '2013-10-10', 'datetime': '2015-10-21 13:44:00', 'monthyear': '2015-10-21T13:44:00', 'name': '*Sherry', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.671416059979, 'location_long': -97.4933117572637, 'age_upon_outcome_in_weeks': 105.938888888889, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bf9'), 'rec_num': 9983, 'age_upon_outcome': '6 years', 'animal_id': 'A680988', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Brown Tabby/White', 'date_of_birth': '2008-06-10', 'datetime': '2014-06-12 19:12:00', 'monthyear': '2014-06-12T19:12:00', 'name': '', 'outcome_subtype': 'SCRP', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.3531104611002, 'location_long': -97.6064286108779, 'age_upon_outcome_in_weeks': 313.4, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bfa'), 'rec_num': 9996, 'age_upon_outcome': '3 weeks', 'animal_id': 'A678494', 'animal_type': 'Cat', 'breed': 'Siamese Mix', 'color': 'Tortie Point', 'date_of_birth': '2014-04-17', 'datetime': '2014-05-09 15:28:00', 'monthyear': '2014-05-09T15:28:00', 'name': '', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.7189647350677, 'location_long': -97.7050552750463, 'age_upon_outcome_in_weeks': 3.23492063492063, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bfb'), 'rec_num': 9995, 'age_upon_outcome': '3 years', 'animal_id': 'A733093', 'animal_type': 'Dog', 'breed': 'German Shepherd Mix', 'color': 'Black/Tan', 'date_of_birth': '2013-08-17', 'datetime': '2016-08-23 18:59:00', 'monthyear': '2016-08-23T18:59:00', 'name': '*Maggie', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.5925731713884, 'location_long': -97.6404482936729, 'age_upon_outcome_in_weeks': 157.541567460317, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bfc'), 'rec_num': 9997, 'age_upon_outcome': '5 years', 'animal_id': 'A745429', 'animal_type': 'Cat', 'breed': 'Domestic Shorthair Mix', 'color': 'Black', 'date_of_birth': '2012-03-17', 'datetime': '2017-03-22 12:08:00', 'monthyear': '2017-03-22T12:08:00', 'name': '', 'outcome_subtype': 'Partner', 'outcome_type': 'Transfer', 'sex_upon_outcome': 'Intact Female', 'location_lat': 30.3020557753236, 'location_long': -97.3259884527128, 'age_upon_outcome_in_weeks': 261.643650793651, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bfd'), 'rec_num': 9998, 'age_upon_outcome': '2 months', 'animal_id': 'A697165', 'animal_type': 'Dog', 'breed': 'Labrador Retriever/Anatol Shepherd', 'color': 'White/Black', 'date_of_birth': '2015-02-18', 'datetime': '2015-05-03 00:00:00', 'monthyear': '2015-05-03T00:00:00', 'name': '*Zoey', 'outcome_subtype': 'Offsite', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Spayed Female', 'location_lat': 30.4778964076145, 'location_long': -97.3569292863629, 'age_upon_outcome_in_weeks': 10.5714285714286, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bfe'), 'rec_num': 9999, 'age_upon_outcome': '2 months', 'animal_id': 'A665304', 'animal_type': 'Dog', 'breed': 'Newfoundland/Australian Cattle Dog', 'color': 'Black/White', 'date_of_birth': '2013-08-16', 'datetime': '2013-10-20 17:46:00', 'monthyear': '2013-10-20T17:46:00', 'name': 'Flynn', 'outcome_subtype': '', 'outcome_type': 'Adoption', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.3822258965608, 'location_long': -97.3215567924164, 'age_upon_outcome_in_weeks': 9.39146825396825, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3bff'), 'rec_num': 9978, 'age_upon_outcome': '3 years', 'animal_id': 'A682924', 'animal_type': 'Dog', 'breed': 'Belgian Malinois Mix', 'color': 'Tan/Black', 'date_of_birth': '2012-01-17', 'datetime': '2015-05-10 18:34:00', 'monthyear': '2015-05-10T18:34:00', 'name': 'Neptune', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.6211584698595, 'location_long': -97.7278022547381, 'age_upon_outcome_in_weeks': 172.824801587302, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6514ce37fe7329bea5cd3c00'), 'rec_num': 10000, 'age_upon_outcome': '4 weeks', 'animal_id': 'A728994', 'animal_type': 'Other', 'breed': 'Bat', 'color': 'Red', 'date_of_birth': '2016-05-12', 'datetime': '2016-06-12 12:48:00', 'monthyear': '2016-06-12T12:48:00', 'name': '', 'outcome_subtype': 'Rabies Risk', 'outcome_type': 'Euthanasia', 'sex_upon_outcome': 'Unknown', 'location_lat': 30.6664774192579, 'location_long': -97.4033754809296, 'age_upon_outcome_in_weeks': 4.5047619047619, 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519a62b203e3764ae8c12d2'), 'name': 'Test', 'type': 'Dog', 'age': 3, 'breed': 'Boxer', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519a66c321efabb5bf224d9'), 'name': 'Test', 'type': 'Dog', 'age': 3, 'breed': 'Boxer', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519a68fc738007718260e53'), 'name': 'Test', 'type': 'Dog', 'age': 3, 'breed': 'Boxer', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519a8bd9591a83ec53e84ff'), 'name': 'Test', 'type': 'Dog1', 'age': 3, 'breed': 'Boxer', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519a9824514996ed4c95671'), 'name': 'Test', 'type': 'Dog1', 'age': 3, 'breed': 'Boxer', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519aa17538575f425bfab71'), 'name': 'Test', 'type': 'Dog1', 'age': 3, 'breed': 'Boxer', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519ab4e0c16a6e8946fee43'), 'name': 'Buddy', 'type': 'Pup', 'age': 1, 'breed': 'Blue PitBull', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519b28131f9969939e18226'), 'name': 'Buddy', 'type': 'Pup', 'age': 1, 'breed': 'Blue PitBull', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519b968e99ec5a93e663400'), 'name': 'Buddy', 'type': 'Pup', 'age': 2, 'breed': 'Blue PitBull', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519b9caa156c6e3cc77f634'), 'name': 'Buddy', 'type': 'Pup', 'age': 2, 'breed': 'Blue PitBull', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519ba2a4bfb42e9b2f4ade7'), 'name': 'Buddy', 'type': 'Pup', 'age': 2, 'breed': 'Blue PitBull', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519bb0b52454ea34db520be'), 'name': 'Buddy', 'type': 'Pup', 'age': 2, 'breed': 'Blue PitBull', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519bc651232966562fed5b2'), 'name': 'Buddy', 'type': 'Pup', 'age': 2, 'breed': 'Blue PitBull', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519bd188124acd476048e47'), 'name': 'Buddy', 'type': 'Pup', 'age': 2, 'breed': 'Blue PitBull', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519bd4850006d94d575d190'), 'name': 'Buddy', 'type': 'Pup', 'age': 2, 'breed': 'Blue PitBull', 'rescue_type': 'unknown'}
# {'_id': ObjectId('6519bf8289b2dc17e0a53e37'), 'name': 'Buddy', 'type': 'Pup', 'age': 2, 'breed': 'Blue PitBull', 'rescue_type': 'unknown'}

# %%
@app.callback(
    Output('breed-count', 'children'),
    Input('rescue-filter', 'value')
)
def update_breed_count(selected_rescue_type):
    if selected_rescue_type == 'reset':
        return f'Total Breeds: {len(df)}'
    
    # Initialize a count variable
    count = 0
    
    # Iterate through the DataFrame and count breeds based on selected rescue type
    for index, row in df.iterrows():
        breed = row['breed']
        rescue_types = row['rescue_type']
        
        # Check if the selected rescue type matches any of the breed's rescue types
        if selected_rescue_type in rescue_types:
            count += 1
    
    return f'Breeds with {selected_rescue_type} Rescue: {count}'

# %%
@app.callback(
    [Output('datatable-id', 'data'), Output('datatable-id', 'columns')],
    [Input('btn-all', 'n_clicks')] + [Input(f'btn-{animal_type}', 'n_clicks') for animal_type in unq_animal_types] + [Input('rescue-filter', 'value')],
    prevent_initial_call=True
)
def update_dashboard(*args):
    # Extract the values from the *args list
    btn_all_clicks, *btn_type_click, rescue_filter = args

    context = dash.callback_context
    button_id = context.triggered[0]['prop_id'].split('.')[0]
    
    # Determine the selected animal type
    if button_id == 'btn-all':
        selected_animal_type = None
    else:
        selected_animal_type = button_id.split('-')[1]

    # Filter the data based on the selected animal type
    if selected_animal_type:
        filtered_data = [record for record in data if record['animal_type'] == selected_animal_type]
    else:
        filtered_data = data

    # Show or hide the rescue filter based on the selected animal type
    rescue_filter_style = {'display': 'block' if selected_animal_type == 'dog' else 'none'}

    # Filter the data based on the selected rescue type
    if rescue_filter != 'reset':
        filtered_data = [record for record in filtered_data if record['rescue_type'] == rescue_filter]

    # Define the columns for the datatable
    columns = [{"name": i, "id": i, "deletable": False, "selectable": True} for i in df.columns]

    return filtered_data, columns

# %%
@app.callback(
    Output('bubble-plot', 'figure'),
    Output('datatable-id', 'derived_viewport_data'),
    Output('graph-id', "children"),
    Input('rescue-filter', 'value'),
    [Input(f'btn-{animal_type}', 'n_clicks') for animal_type in unq_animal_types],
    prevent_initial_call=True
)
def update_plot(rescue_filter, *btn_clicks):
    dff = df.copy()

    # Calculate total counts of each rescue type for dogs
    if rescue_filter == 'reset':
        dff_dogs = dff[dff['animal_type'] == 'Dog']
        rescue_counts = dff_dogs['rescue_type'].value_counts()
    else:
        dff_dogs = dff[(dff['animal_type'] == 'Dog') & (dff['rescue_type'] == rescue_filter)]
        rescue_counts = dff_dogs['rescue_type'].value_counts()        

    # Calculate the total count of all rescue dogs
    total_rescue_dogs = len(dff_dogs)

    # Create a size column based on rescue counts for each data point
    dff_dogs['size'] = dff_dogs['rescue_type'].map(rescue_counts)

    # Create the bubble plot
    fig = px.scatter(
        dff_dogs,
        x='age_upon_outcome_in_weeks',
        y='outcome_type',
        size='size',  # Use the 'size' column for sizing
        color='breed',
        hover_name='animal_type'
    )

    return fig, dff_dogs.to_dict('records'), total_rescue_dogs

# %%
# Map
@app.callback(
    Output('map-id', "children"),
    Input('datatable-id', "derived_viewport_data"),
    Input('datatable-id', 'selected_rows'),
    prevent_initial_call = True
)
def update_map(viewData, selected_rows):
    dff = pd.DataFrame.from_dict(viewData)
    
    if selected_rows is not None and len(selected_rows) > 0:
        selected_row_index = selected_rows[0]

        if selected_row_index >= 0 and selected_row_index < len(dff):
            selected_row = dff.iloc[selected_row_index]

            latitude = selected_row['location_lat']
            longitude = selected_row['location_long']

            return [
                dl.Map(
                    style={'width': '1000px', 'height': '500px'},
                    center=[30.75, -97.48],
                    zoom=10,
                    children=[
                        dl.TileLayer(id="base-layer-id"),
                        dl.Marker(
                            position=(latitude, longitude),
                            children=[
                                dl.Tooltip('Austin Animal Shelter'),  # Replace with relevant tooltip data
                                dl.Popup([
                                    html.H1(selected_row["animal_type"]),
                                    html.P(selected_row["breed"])  # Replace with relevant popup content
                                ])
                            ]
                        )
                    ]
                )
            ]

    # Return an empty list when no row is selected or the selected index is out of bounds
    return []



app.run_server(debug=True)
# Out:
# Dash app running on http://127.0.0.1:10079/

# %%
#display all column names of DataFrame
print(df.columns.tolist())
df.dtypes
print(df.head())
# Out:
# ['rec_num', 'age_upon_outcome', 'animal_id', 'animal_type', 'breed', 'color', 'date_of_birth', 'datetime', 'monthyear', 'name', 'outcome_subtype', 'outcome_type', 'sex_upon_outcome', 'location_lat', 'location_long', 'age_upon_outcome_in_weeks', 'rescue_type', 'age', 'type']
#    rec_num age_upon_outcome animal_id animal_type                   breed  \
# 0      1.0          3 years   A746874         Cat  Domestic Shorthair Mix
# 1      2.0           1 year   A725717         Cat  Domestic Shorthair Mix
# 2      5.0          2 years   A691584         Dog  Labrador Retriever Mix
# 3      4.0         7 months   A733653         Cat             Siamese Mix
# 4      7.0          2 years   A673830         Dog            Pit Bull Mix
#
#           color date_of_birth             datetime            monthyear  \
# 0   Black/White    2014-04-10  2017-04-11 09:00:00  2017-04-11T09:00:00
# 1  Silver Tabby    2015-05-02  2016-05-06 10:49:00  2016-05-06T10:49:00
# 2     Tan/White    2012-11-06  2015-05-30 13:48:00  2015-05-30T13:48:00
# 3    Seal Point    2016-01-25  2016-08-27 18:11:00  2016-08-27T18:11:00
# 4   Black/White    2012-03-03  2014-03-19 15:15:00  2014-03-19T15:15:00
#
#     name outcome_subtype     outcome_type sex_upon_outcome  location_lat  \
# 0                   SCRP         Transfer    Neutered Male     30.506658
# 1                   SCRP         Transfer    Spayed Female     30.652598
# 2   Luke                  Return to Owner    Neutered Male     30.710482
# 3  Kitty                         Adoption    Intact Female     30.318806
# 4  *Seth      Aggressive       Euthanasia    Neutered Male     30.295426
#
#    location_long  age_upon_outcome_in_weeks rescue_type  age type
# 0     -97.340878                 156.767857     unknown  NaN  NaN
# 1     -97.741996                  52.921528     unknown  NaN  NaN
# 2     -97.562297                 133.653571       water  NaN  NaN
# 3     -97.724038                  30.822520     unknown  NaN  NaN
# 4     -97.313664                 106.662202     unknown  NaN  NaN
# /tmp/ipykernel_344796/1756511628.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_344796/1756511628.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_344796/1756511628.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_344796/1756511628.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_344796/1756511628.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_344796/1756511628.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
